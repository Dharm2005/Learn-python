# %% [markdown]
# # Excel Read & Write

# %%
import pandas as pd

ger_uni = pd.read_excel("../data/German_University.xlsx")

ger_uni['IELTS'] = 6.5

ger_uni.to_excel("../warmup-data/new_uni.xlsx", index=False)

# %%
new_ger_uni = pd.read_excel("../warmup-data/new_uni.xlsx")

new_ger_uni
# Out:
#   Unnamed: 0                        Unnamed: 1 Unnamed: 2  \
# 0        No.                Name of University       City
# 1          1              Paderborn University  Paderborn
# 2          2             University of Potsdam    Potsdam
# 3          3           University of Göttingen  Göttingen
# 4          4  Dresden University of Technology    Dresden
# 5          5               University of Bonn        Bonn
# 6          6              University of Passau     Passau
# 7          7                               NaN        NaN
#
#                               Unnamed: 3                  Unnamed: 4  \
# 0                           Program Name                      Intake
# 1  Master of Science in Computer Science  Winter and summer semester
# 2                      Master of Science  Winter and summer semester
# 3                      Master of Science  Winter and summer semester
# 4                       Computer Science  Winter and summer semester
# ...
